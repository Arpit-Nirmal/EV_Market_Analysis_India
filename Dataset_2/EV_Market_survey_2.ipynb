# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
data=pd.read_csv("Data.csv")
data_copy=data
data.head()
# Out:
#    Unnamed: 0  Age       City Profession Marital Status Education  \
# 0           0   30      Nabha        NaN         Single  Graduate
# 1           1   27       Pune        NaN         Single  Graduate
# 2           2   32  Kashipur         NaN         Single  Graduate
# 3           3   55       Pune   Business         Single  Graduate
# 4           4   26     Satara        NaN         Single  Graduate
#
#    No. of Family members  Annual Income  \
# 0                      5   1.193876e+06
# 1                      4   1.844540e+06
# 2                      4   2.948150e+06
# 3                      3   2.832380e+06
# 4                      4   2.638751e+06
#
#   Would you prefer replacing all your vehicles to Electronic vehicles?  \
# 0                                              Maybe
# 1                                                Yes
# 2                                                Yes
# 3                                              Maybe
# ...

# %%
data=data.drop("Unnamed: 0",axis=1)

# %%
data.head()
# Out:
#    Age       City Profession Marital Status Education  No. of Family members  \
# 0   30      Nabha        NaN         Single  Graduate                      5
# 1   27       Pune        NaN         Single  Graduate                      4
# 2   32  Kashipur         NaN         Single  Graduate                      4
# 3   55       Pune   Business         Single  Graduate                      3
# 4   26     Satara        NaN         Single  Graduate                      4
#
#    Annual Income  \
# 0   1.193876e+06
# 1   1.844540e+06
# 2   2.948150e+06
# 3   2.832380e+06
# 4   2.638751e+06
#
#   Would you prefer replacing all your vehicles to Electronic vehicles?  \
# 0                                              Maybe
# 1                                                Yes
# 2                                                Yes
# 3                                              Maybe
# 4                                                Yes
#
# ...

# %% [markdown]
# Data Visualisation

# %%
plt.figure(figsize=(6, 6))
sns.distplot(data["Age"], color='orange')

plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# Distribution by Professions

# %%
plt.figure(figsize=(4, 4))
profession_counts = data["Profession"].value_counts()
plt.pie(profession_counts, labels=profession_counts.index, autopct="%0.1f%%", startangle=140)
plt.title('Distribution of Professions')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
data["City"].unique()
# Out:
# array(['Nabha', 'Pune', 'Kashipur ', 'Satara', 'Noida', 'Delhi', 'Mumbai',
#        'pune', 'solapur', 'Haldwani ', 'Nellore ', 'Pune ', 'Haldwani',
#        'Banglore ', 'Faridabad ', 'Nagpur', 'Chandrapur ', 'Chennai',
#        'Gurugram ', 'Nashik', 'Bengaluru', 'Mumbai ', 'Hakdwani',
#        'Patiyala', 'pUNE', 'Ahmedabad', 'Karnal', 'Rewari', 'New Delhi',
#        'Serampore', 'Jhansi', 'New Delhi ', 'Jalandhar', 'Delhi ',
#        'nashik'], dtype=object)

# %%
data["City"]=data["City"].replace({"Pune ":"Pune","pUNE":"Pune","pune":"Pune","Pune":"Pune"})
data["City"]=data["City"].replace({"Banglore ":"Bengaluru"})
data["City"]=data["City"].replace({"Hakdwani":"Haldwani","Haldwani ":"Haldwani"})
data["City"]=data["City"].replace({"New Delhi ":"Delhi","Delhi ":"Delhi"})
data["City"]=data["City"].replace({"nashik":"Nashik"})
data["City"]=data["City"].replace({"Mumbai ":"Mumbai"})

# %%
data["City"].unique()
# Out:
# array(['Nabha', 'Pune', 'Kashipur ', 'Satara', 'Noida', 'Delhi', 'Mumbai',
#        'solapur', 'Haldwani', 'Nellore ', 'Bengaluru', 'Faridabad ',
#        'Nagpur', 'Chandrapur ', 'Chennai', 'Gurugram ', 'Nashik',
#        'Patiyala', 'Ahmedabad', 'Karnal', 'Rewari', 'New Delhi',
#        'Serampore', 'Jhansi', 'Jalandhar'], dtype=object)

# %% [markdown]
# Location wise data

# %%
top_cities = data["City"].value_counts().iloc[:5].index

plt.figure(figsize=(10, 6))
sns.countplot(x="City", data=data, order=top_cities, palette="viridis")
plt.title('Top Cities')
plt.xlabel('City')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Distribution by Income

# %%
plt.figure(figsize=(6, 6))
sns.histplot(data["Annual Income"], color="orange", bins=70)
plt.title('Distribution of Annual Income')

plt.xlabel('Annual Income')
plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %% [markdown]
# Opinion on Are Electronic Vehicles Economical?

# %%
value_counts = data["Do you think Electronic Vehicles are economical?"].value_counts()
plt.figure(figsize=(4, 4))
plt.pie(value_counts, labels=value_counts.index, autopct='%0.1f%%', colors=['blue', 'lightgreen','red'])
plt.title('Are Electronic Vehicles Economical?')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# Preference for 2/3/4 wheeler in EVs

# %%
value_counts = data["Preference for wheels in EV"].value_counts()
plt.figure(figsize=(4, 4))
plt.pie(value_counts, labels=value_counts.index, autopct='%0.1f%%', colors=['orange', 'green','orchid'])
plt.title('Preference for 2/3/4 wheeler in EVs')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# Opinion on Money Spending Preference on Electronic Vehicle

# %%
value_counts = data["How much money could you spend on an Electronic vehicle?"].value_counts()
plt.figure(figsize=(6, 6))
bar_plot = value_counts.plot(kind="bar", color='orange')
plt.title('Money Spending Preference on Electronic Vehicle', color='orange')
plt.xlabel('Amount Range')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Current Vehicle Brand Ownership

# %%
plt.figure(figsize=(7, 7))
data["Which brand of vehicle do you currently own?"].value_counts().plot(kind="bar", color='seagreen')
plt.title('Current Vehicle Brand Ownership')
plt.xlabel('Vehicle Brand')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Opinion on EVs Economic Viability by Education Level

# %%
plt.figure(figsize=(6, 6))
sns.countplot(x="Education", data=data, hue="Do you think Electronic Vehicles are economical?", palette="husl")
plt.title('Distribution of Opinion on EVs Economic Viability by Education Level')
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Economical EVs?', loc='upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
def label_encoder(data,column):
    label_encoder=LabelEncoder()
    return label_encoder.fit_transform(data[column].astype(str))

# %%
data.head()
# Out:
#    Age       City Profession Marital Status Education  No. of Family members  \
# 0   30      Nabha        NaN         Single  Graduate                      5
# 1   27       Pune        NaN         Single  Graduate                      4
# 2   32  Kashipur         NaN         Single  Graduate                      4
# 3   55       Pune   Business         Single  Graduate                      3
# 4   26     Satara        NaN         Single  Graduate                      4
#
#    Annual Income  \
# 0   1.193876e+06
# 1   1.844540e+06
# 2   2.948150e+06
# 3   2.832380e+06
# 4   2.638751e+06
#
#   Would you prefer replacing all your vehicles to Electronic vehicles?  \
# 0                                              Maybe
# 1                                                Yes
# 2                                                Yes
# 3                                              Maybe
# 4                                                Yes
#
# ...

# %%
data['City']= label_encoder(data,'City')
data['Profession']= label_encoder(data,'Profession')
data['Marital Status']= label_encoder(data,'Marital Status')
data['Education']= label_encoder(data,'Education')

# %%
data.head()
# Out:
#    Age  City  Profession  Marital Status  Education  No. of Family members  \
# 0   30    13           3               1          0                      5
# 1   27    20           3               1          0                      4
# 2   32    11           3               1          0                      4
# 3   55    20           0               1          0                      3
# 4   26    22           3               1          0                      4
#
#    Annual Income  \
# 0   1.193876e+06
# 1   1.844540e+06
# 2   2.948150e+06
# 3   2.832380e+06
# 4   2.638751e+06
#
#   Would you prefer replacing all your vehicles to Electronic vehicles?  \
# 0                                              Maybe
# 1                                                Yes
# 2                                                Yes
# 3                                              Maybe
# 4                                                Yes
#
#   If Yes/Maybe what type of  EV would you prefer?  \
# ...

# %%
data['Would you prefer replacing all your vehicles to Electronic vehicles?']= label_encoder(data,'Would you prefer replacing all your vehicles to Electronic vehicles?')
data['If Yes/Maybe what type of  EV would you prefer?']= label_encoder(data,'If Yes/Maybe what type of  EV would you prefer?')
data['Do you think Electronic Vehicles are economical?']= label_encoder(data,'Do you think Electronic Vehicles are economical?')
data['Which brand of vehicle do you currently own?']= label_encoder(data,'Which brand of vehicle do you currently own?')
data['Do you think Electronic vehicles will replace fuel cars in India?']= label_encoder(data,'Do you think Electronic vehicles will replace fuel cars in India?')
data['How much money could you spend on an Electronic vehicle?']= label_encoder(data,'How much money could you spend on an Electronic vehicle?')

# %%
data.head()
# Out:
#    Age  City  Profession  Marital Status  Education  No. of Family members  \
# 0   30    13           3               1          0                      5
# 1   27    20           3               1          0                      4
# 2   32    11           3               1          0                      4
# 3   55    20           0               1          0                      3
# 4   26    22           3               1          0                      4
#
#    Annual Income  \
# 0   1.193876e+06
# 1   1.844540e+06
# 2   2.948150e+06
# 3   2.832380e+06
# 4   2.638751e+06
#
#    Would you prefer replacing all your vehicles to Electronic vehicles?  \
# 0                                                  0
# 1                                                  2
# 2                                                  2
# 3                                                  0
# 4                                                  2
#
#    If Yes/Maybe what type of  EV would you prefer?  \
# ...

# %% [markdown]
# K Means Model

# %%
y=data["City"]
x=data.drop(["City"],axis=1)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def vif(x):
    vif=pd.DataFrame()
    vif['variables']=x.columns
    vif['VIF']=[variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
    return(vif)

# %%
x=data.iloc[:,:-1]

# %%
vif(x)
# Out:
#                                             variables        VIF
# 0                                                 Age   8.048885
# 1                                                City   7.927265
# 2                                          Profession   4.699440
# 3                                      Marital Status   2.716670
# 4                                           Education   1.449336
# 5                               No. of Family members   8.304938
# 6                                       Annual Income   5.770562
# 7   Would you prefer replacing all your vehicles t...   4.140082
# 8     If Yes/Maybe what type of  EV would you prefer?   7.104678
# 9    Do you think Electronic Vehicles are economical?   6.377955
# 10       Which brand of vehicle do you currently own?   3.886415
# 11  How much money could you spend on an Electroni...  13.297872
# 12                        Preference for wheels in EV  12.552252

# %% [markdown]
# Finding the number of clusters using Elbow Method

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(data)
    wcss.append(kmeans.inertia_)

plt.plot(range(1, 11), wcss)
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.title('Elbow Method')
plt.grid()
plt.show()

# %% [markdown]
# Apply the KMeans Clustering algorithm

# %%
# Perform K-means clustering with the optimal number of clusters
kmeans = KMeans(n_clusters=4, init='k-means++', random_state=42)
kmeans.fit(data)
# Out:
# KMeans(n_clusters=4, random_state=42)

# %%
kmeans_predict=KMeans(n_clusters=4,random_state=123)
clusters=kmeans_predict.fit_predict(data)
data_copy["Clusters"]=clusters

# %%
data_copy.head()
# Out:
#    Unnamed: 0  Age       City Profession Marital Status Education  \
# 0           0   30      Nabha        NaN         Single  Graduate
# 1           1   27       Pune        NaN         Single  Graduate
# 2           2   32  Kashipur         NaN         Single  Graduate
# 3           3   55       Pune   Business         Single  Graduate
# 4           4   26     Satara        NaN         Single  Graduate
#
#    No. of Family members  Annual Income  \
# 0                      5   1.193876e+06
# 1                      4   1.844540e+06
# 2                      4   2.948150e+06
# 3                      3   2.832380e+06
# 4                      4   2.638751e+06
#
#   Would you prefer replacing all your vehicles to Electronic vehicles?  \
# 0                                              Maybe
# 1                                                Yes
# 2                                                Yes
# 3                                              Maybe
# ...

# %%
data_copy["Clusters"].value_counts()
# Out:
# Clusters
# 1    434
# 0    366
# 3    193
# 2      7
# Name: count, dtype: int64

# %% [markdown]
# Bifurcating the data according to the cluster

# %%
Cluster_1=data_copy[data_copy.Clusters==0]
Cluster_2=data_copy[data_copy.Clusters==1]
Cluster_3=data_copy[data_copy.Clusters==2]
Cluster_4=data_copy[data_copy.Clusters==3]

# %% [markdown]
# **Demographic Segment**

# %% [markdown]
# Age Group

# %%
clusters = [Cluster_1, Cluster_2, Cluster_3, Cluster_4]
labels = [[29, 28, 30, 31, 27], [29, 28, 30, 25, 26], [30, 26, 29, 56, 28], [31, 30, 29, 27, 28]]

for i, cluster in enumerate(clusters):
    plt.figure(figsize=(4, 4))
    age_counts = cluster["Age"].value_counts().head()
    plt.title(f"Cluster_{i+1}")
    plt.pie(age_counts, labels=labels[i], autopct='%1.1f%%', startangle=140)
    plt.axis('equal')
    plt.show()

# %% [markdown]
# Profession

# %%
clusters = [Cluster_1, Cluster_2, Cluster_3, Cluster_4]

for i, cluster in enumerate(clusters, start=1):
    plt.figure(figsize=(4, 4))
    profession_counts = cluster["Profession"].value_counts().head()
    mylabels = profession_counts.index.tolist()  # Use actual categories as labels
    plt.title(f"Cluster_{i}")
    plt.pie(profession_counts, labels=mylabels, autopct='%1.1f%%', startangle=140)
    plt.axis('equal')
    plt.show()

# %% [markdown]
# Income group

# %%
[Cluster_1["Annual Income"].mean(),
Cluster_2["Annual Income"].mean(),
Cluster_3["Annual Income"].mean(),
Cluster_4["Annual Income"].mean()]
# Out:
# [2058283.2568936772, 2808684.4456641255, 10737228.104106281, 1092645.106776382]

# %% [markdown]
# Geographic Segments

# %%
clusters = [Cluster_1, Cluster_2, Cluster_3, Cluster_4]

for i, cluster in enumerate(clusters, start=1):
    plt.figure(figsize=(4, 4))
    city_counts = cluster["City"].value_counts().head()
    mylabels = city_counts.index.tolist()
    plt.title(f"Cluster_{i}")
    plt.pie(city_counts, labels=mylabels, autopct='%1.1f%%', startangle=20)
    plt.axis('equal')
    plt.show()

# %%
[Cluster_1["No. of Family members"].value_counts().head(),
Cluster_2["No. of Family members"].value_counts().head(),
Cluster_3["No. of Family members"].value_counts().head(),
Cluster_4["No. of Family members"].value_counts().head()]

mylabels=[4,5,3,8,6]
plt.title("Cluster_1")
plt.pie(Cluster_1["No. of Family members"].value_counts().head(),labels=mylabels)
plt.show()

mylabels1=[4,5,3,6,2]
plt.title("Cluster_2")
plt.pie(Cluster_2["No. of Family members"].value_counts().head(),labels=mylabels1)
plt.show()

mylabels2=[4,6,5,8]
plt.title("Cluster_3")
plt.pie(Cluster_3["No. of Family members"].value_counts().head(),labels=mylabels2)
plt.show()

mylabels3=[4,5,3,6,8]
plt.title("Cluster_4")
plt.pie(Cluster_4["No. of Family members"].value_counts().head(),labels=mylabels3)
plt.show()

# %% [markdown]
# EV type Preference

# %%
clusters = [Cluster_1, Cluster_2, Cluster_3, Cluster_4]

for i, cluster in enumerate(clusters, start=1):
    plt.figure(figsize=(4, 4))
    preference_counts = cluster["Preference for wheels in EV"].value_counts().head()
    mylabels = preference_counts.index.tolist()
    plt.title(f"Cluster_{i}")
    plt.pie(preference_counts, labels=mylabels, autopct='%1.1f%%', startangle=210)
    plt.axis('equal')
    plt.show()
    print(preference_counts)
# Out:
# Preference for wheels in EV
# 4    230
# 2    100
# 3     36
# Name: count, dtype: int64
# Preference for wheels in EV
# 4    266
# 2    126
# 3     42
# Name: count, dtype: int64
# Preference for wheels in EV
# 4    4
# 2    2
# 3    1
# Name: count, dtype: int64
# Preference for wheels in EV
# 4    129
# 2     52
# 3     12
# Name: count, dtype: int64

# %%
[Cluster_1['Which brand of vehicle do you currently own?'].value_counts().head(),
 Cluster_2['Which brand of vehicle do you currently own?'].value_counts().head(),
 Cluster_3['Which brand of vehicle do you currently own?'].value_counts().head(),
 Cluster_4['Which brand of vehicle do you currently own?'].value_counts().head()]

mylabels = ["Tata","Hyundai","KIA","Honda","Nissan"]
plt.title("Cluster_1")
plt.pie(Cluster_1['Which brand of vehicle do you currently own?'].value_counts().head(),labels= mylabels)
plt.show()

mylabels1 = ["Tata","Hyundai","Honda","KIA","Nissan"]
plt.title("Cluster_2")
plt.pie(Cluster_2['Which brand of vehicle do you currently own?'].value_counts().head(),labels= mylabels1)
plt.show()

mylabels2 = ["Tata","KIA","MG","Honda","Hyundai"]
plt.title("Cluster_3")
plt.pie(Cluster_3['Which brand of vehicle do you currently own?'].value_counts().head(),labels= mylabels2)
plt.show()

mylabels3 = ["Tata","Hyundai","KIA","Honda","Nissan"]
plt.title("Cluster_4")
plt.pie(Cluster_4['Which brand of vehicle do you currently own?'].value_counts().head(),labels= mylabels3)
plt.show()

# %%
[Cluster_1["How much money could you spend on an Electronic vehicle?"].value_counts().head(),
Cluster_2["How much money could you spend on an Electronic vehicle?"].value_counts().head(),
Cluster_3["How much money could you spend on an Electronic vehicle?"].value_counts().head(),
Cluster_4["How much money could you spend on an Electronic vehicle?"].value_counts().head()]
# Out:
# [How much money could you spend on an Electronic vehicle?
#  <15 lakhs    159
#  <5 lakhs     106
#  <25 lakhs     69
#  >25 lakhs     14
#  700000         6
#  Name: count, dtype: int64,
#  How much money could you spend on an Electronic vehicle?
#  <15 lakhs    219
#  <5 lakhs     128
#  <25 lakhs     49
#  >25 lakhs     15
#  1200000        7
#  Name: count, dtype: int64,
#  How much money could you spend on an Electronic vehicle?
#  <15 lakhs    3
#  <5 lakhs     3
#  <25 lakhs    1
#  Name: count, dtype: int64,
#  How much money could you spend on an Electronic vehicle?
#  <15 lakhs    102
#  <5 lakhs      51
#  <25 lakhs     29
#  >25 lakhs      5
#  1200000        3
#  Name: count, dtype: int64]

# %% [markdown]
# **<15 lakh for EV - 48.3%, <5 lakh for EV - 28.8%, <25 lakh for EV - 14.8%, >25 lakh for EV - 3.4%**

# %% [markdown]
# Behavioral Segmentation

# %% [markdown]
# Preference for replacing all vehicles to Electronic vehicles?

# %%
[Cluster_1["Would you prefer replacing all your vehicles to Electronic vehicles?"].value_counts().head(),
Cluster_2["Would you prefer replacing all your vehicles to Electronic vehicles?"].value_counts().head(),
Cluster_3["Would you prefer replacing all your vehicles to Electronic vehicles?"].value_counts().head(),
Cluster_4["Would you prefer replacing all your vehicles to Electronic vehicles?"].value_counts().head()]

mylabels0 = ["Yes","Maybe","No"]
plt.title("Cluster_1")
plt.pie(Cluster_1["Would you prefer replacing all your vehicles to Electronic vehicles?"].value_counts().head(),labels= mylabels0)
plt.show()

mylabels1 = ["Yes","Maybe","No"]
plt.title("Cluster_2")
plt.pie(Cluster_2["Would you prefer replacing all your vehicles to Electronic vehicles?"].value_counts().head(),labels= mylabels1)
plt.show()

mylabels2 = ["Yes"]
plt.title("Cluster_3")
plt.pie(Cluster_3["Would you prefer replacing all your vehicles to Electronic vehicles?"].value_counts().head(),labels= mylabels2)
plt.show()

mylabels3 = ["Yes","Maybe","No"]
plt.title("Cluster_4")
plt.pie(Cluster_4["Would you prefer replacing all your vehicles to Electronic vehicles?"].value_counts().head(),labels= mylabels3)
plt.show()

# %% [markdown]
# **If Yes/Maybe what type of EV would you prefer?**

# %%
print(Cluster_1['If Yes/Maybe what type of  EV would you prefer?'].value_counts().head())
mylabels = ["SUV","Sedan","Hatchback","Liftback","Cabrio"]
plt.title("Cluster_1")
plt.pie(Cluster_1['If Yes/Maybe what type of  EV would you prefer?'].value_counts().head(),labels= mylabels)
plt.show()

print(Cluster_2['If Yes/Maybe what type of  EV would you prefer?'].value_counts().head())
mylabels1 = ["SUV","Sedan","Hatchback","Liftback","Cabrio"]
plt.title("Cluster_2")
plt.pie(Cluster_2['If Yes/Maybe what type of  EV would you prefer?'].value_counts().head(),labels= mylabels1)
plt.show()

print(Cluster_3['If Yes/Maybe what type of  EV would you prefer?'].value_counts().head())
mylabels2 = ["SUV","Sedan","Hatchback","Liftback"]
plt.title("Cluster_3")
plt.pie(Cluster_3['If Yes/Maybe what type of  EV would you prefer?'].value_counts().head(),labels= mylabels2)
plt.show()

print(Cluster_4['If Yes/Maybe what type of  EV would you prefer?'].value_counts().head())
mylabels3 = ["SUV","Sedan","Hatchback","Liftback","Cabrio"]
plt.title("Cluster_4")
plt.pie(Cluster_4['If Yes/Maybe what type of  EV would you prefer?'].value_counts().head(),labels= mylabels3)
plt.show()
# Out:
# If Yes/Maybe what type of  EV would you prefer?
# SUV          175
# Sedan         84
# Hatchback     54
# Liftback      43
# Cabrio        10
# Name: count, dtype: int64
# If Yes/Maybe what type of  EV would you prefer?
# SUV          193
# Sedan        116
# Hatchback     63
# Liftback      46
# Cabrio        16
# Name: count, dtype: int64
# If Yes/Maybe what type of  EV would you prefer?
# SUV          3
# Sedan        2
# Hatchback    1
# Liftback     1
# Name: count, dtype: int64
# If Yes/Maybe what type of  EV would you prefer?
# SUV          96
# Sedan        38
# Liftback     30
# Hatchback    26
# Cabrio        3
# Name: count, dtype: int64

# %% [markdown]
# **Do you think Electronic Vehicles are economical?**

# %%
clusters = [Cluster_1, Cluster_2, Cluster_3, Cluster_4]
titles = ["Cluster_1", "Cluster_2", "Cluster_3", "Cluster_4"]
mylabels = ["Yes", "Maybe", "No"]

for i, cluster in enumerate(clusters):
    plt.figure()
    plt.title(titles[i])
    values = cluster["Do you think Electronic Vehicles are economical?"].value_counts().head()
    plt.pie(values, labels=mylabels, autopct='%1.1f%%', pctdistance=0.85)
    plt.legend(labels=[f'{label} ({count})' for label, count in zip(mylabels, values)])
    plt.show()

# %% [markdown]
# **Do you think Electronic vehicles will replace fuel cars in India?**

# %%
import matplotlib.pyplot as plt

clusters = [Cluster_1, Cluster_2, Cluster_3, Cluster_4]
titles = ["Cluster_1", "Cluster_2", "Cluster_3", "Cluster_4"]

for i, cluster in enumerate(clusters):
    plt.figure()
    plt.title(titles[i])
    values = cluster["Do you think Electronic vehicles will replace fuel cars in India?"].value_counts().head()
    labels = values.index.tolist()  # Get the unique value labels dynamically
    plt.pie(values, labels=labels, autopct='%1.1f%%', pctdistance=0.85)
    plt.show()

# %%
[Cluster_1["Do you think Electronic vehicles will replace fuel cars in India?"].value_counts().head(),
Cluster_2["Do you think Electronic vehicles will replace fuel cars in India?"].value_counts().head(),
Cluster_3["Do you think Electronic vehicles will replace fuel cars in India?"].value_counts().head(),
Cluster_4["Do you think Electronic vehicles will replace fuel cars in India?"].value_counts().head()]
# Out:
# [Do you think Electronic vehicles will replace fuel cars in India?
#  Yes, in <10 years               155
#  Yes, in <20years                133
#  Yes, possibly after 20 years     53
#  I don't think so                 25
#  Name: count, dtype: int64,
#  Do you think Electronic vehicles will replace fuel cars in India?
#  Yes, in <10 years               186
#  Yes, in <20years                176
#  Yes, possibly after 20 years     55
#  I don't think so                 17
#  Name: count, dtype: int64,
#  Do you think Electronic vehicles will replace fuel cars in India?
#  Yes, in <10 years               4
#  Yes, possibly after 20 years    2
#  Yes, in <20years                1
#  Name: count, dtype: int64,
#  Do you think Electronic vehicles will replace fuel cars in India?
#  Yes, in <20years                77
#  Yes, in <10 years               74
#  Yes, possibly after 20 years    22
#  I don't think so                20
#  Name: count, dtype: int64]
